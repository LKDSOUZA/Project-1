# %%
import pandas as pd
import matplotlib.pyplot as plt
import scipy.stats as st
import numpy as np

crime_path = "crimedata1.csv"
crime_data = pd.read_csv(crime_path)
crime_data.head()
# Out:
#    Year Year ending             Offence Division  \
# 0  2022   September  A Crimes against the person
# 1  2022   September  A Crimes against the person
# 2  2022   September  A Crimes against the person
# 3  2022   September  A Crimes against the person
# 4  2022   September  A Crimes against the person
#
#                  Offence Subdivision  \
# 0  A10 Homicide and related offences
# 1   A20 Assault and related offences
# 2   A20 Assault and related offences
# 3   A20 Assault and related offences
# 4                A30 Sexual offences
#
#                                        Offence Group Victim Reports  \
# 0                  A10 Homicide and related offences            187
# 1                                A21 Serious assault         14,306
# 2  A22 Assault police, emergency services or othe...          2,930
# 3                                 A23 Common assault         27,218
# 4                                           A31 Rape          3,659
#
# ...

# %%
# Getting data for 2021
crime_data_21 = crime_data.loc[crime_data["Year"] == 2021]
crime_data_21["Victim Reports"].str.replace(",","").astype(int)
crime_data_21["Victim Reports"] = crime_data_21["Victim Reports"].str.replace(",","").astype(int)

# Getting data for 2020
crime_data_20 = crime_data.loc[crime_data["Year"] == 2020]
crime_data_20["Victim Reports"].str.replace(",","").astype(int)
crime_data_20["Victim Reports"] = crime_data_20["Victim Reports"].str.replace(",","").astype(int)

# Getting data for 2019
crime_data_19 = crime_data.loc[crime_data["Year"] == 2019]
crime_data_19["Victim Reports"].str.replace(",","").astype(int)
crime_data_19["Victim Reports"] = crime_data_19["Victim Reports"].str.replace(",","").astype(int)

# Getting data for 2018
crime_data_18 = crime_data.loc[crime_data["Year"] == 2018]
crime_data_18["Victim Reports"].str.replace(",","").astype(int)
crime_data_18["Victim Reports"] = crime_data_18["Victim Reports"].str.replace(",","").astype(int)
# Out:
# D:\My App\Anaconda\envs\PythonData\lib\site-packages\ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.
# D:\My App\Anaconda\envs\PythonData\lib\site-packages\ipykernel_launcher.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   if __name__ == '__main__':
# D:\My App\Anaconda\envs\PythonData\lib\site-packages\ipykernel_launcher.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# ...

# %%
statistics_raw_data=crime_data_21.copy()

victim_report_mean=statistics_raw_data.groupby(['Offence Division'])["Victim Reports"].mean()
victim_report_median=statistics_raw_data.groupby(['Offence Division'])["Victim Reports"].median()
victim_report_variance=statistics_raw_data.groupby(['Offence Division'])["Victim Reports"].var()
victim_report_sd=statistics_raw_data.groupby(['Offence Division'])["Victim Reports"].std()
victim_report_SEM=statistics_raw_data.groupby(['Offence Division'])["Victim Reports"].sem()

statistics_summary_21 = pd.DataFrame({"Mean victim report": victim_report_mean,
                                  "Median victim report": victim_report_median,
                                  "victim report Variance": victim_report_variance,
                                  "victim report Std. Dev.": victim_report_sd,
                                  "victim report Std. Err." : victim_report_SEM,
                                 
                                 })
statistics_summary_21.head(10)
# Out:
#                                    Mean victim report  Median victim report  \
# Offence Division
# A Crimes against the person               3983.058824                  2045
# B Property and deception offences        11133.916667                  8272
# C Other offences                           131.000000                   131
#
#                                    victim report Variance  \
# Offence Division
# A Crimes against the person                  4.535581e+07
# B Property and deception offences            1.449198e+08
# C Other offences                                      NaN
#
#                                    victim report Std. Dev.  \
# Offence Division
# A Crimes against the person                    6734.672157
# B Property and deception offences             12038.262669
# C Other offences                                       NaN
#
#                                    victim report Std. Err.
# Offence Division
# ...

# %%
statistics_raw_data_20=crime_data_20.copy()

victim_report_mean=statistics_raw_data_20.groupby(['Offence Division'])["Victim Reports"].mean()
victim_report_median=statistics_raw_data_20.groupby(['Offence Division'])["Victim Reports"].median()
victim_report_variance=statistics_raw_data_20.groupby(['Offence Division'])["Victim Reports"].var()
victim_report_sd=statistics_raw_data_20.groupby(['Offence Division'])["Victim Reports"].std()
victim_report_SEM=statistics_raw_data_20.groupby(['Offence Division'])["Victim Reports"].sem()

statistics_summary_20 = pd.DataFrame({"Mean victim report": victim_report_mean,
                                  "Median victim report": victim_report_median,
                                  "victim report Variance": victim_report_variance,
                                  "victim report Std. Dev.": victim_report_sd,
                                  "victim report Std. Err." : victim_report_SEM,
                                 
                                 })
statistics_summary_20.head(10)
# Out:
#                                    Mean victim report  Median victim report  \
# Offence Division
# A Crimes against the person               3922.176471                  2179
# B Property and deception offences        12494.750000                  8405
# C Other offences                           143.000000                   143
#
#                                    victim report Variance  \
# Offence Division
# A Crimes against the person                  4.241472e+07
# B Property and deception offences            1.971629e+08
# C Other offences                                      NaN
#
#                                    victim report Std. Dev.  \
# Offence Division
# A Crimes against the person                    6512.658292
# B Property and deception offences             14041.471214
# C Other offences                                       NaN
#
#                                    victim report Std. Err.
# Offence Division
# ...

# %%
statistics_raw_data_19=crime_data_19.copy()

victim_report_mean=statistics_raw_data_19.groupby(['Offence Division'])["Victim Reports"].mean()
victim_report_median=statistics_raw_data_19.groupby(['Offence Division'])["Victim Reports"].median()
victim_report_variance=statistics_raw_data_19.groupby(['Offence Division'])["Victim Reports"].var()
victim_report_sd=statistics_raw_data_19.groupby(['Offence Division'])["Victim Reports"].std()
victim_report_SEM=statistics_raw_data_19.groupby(['Offence Division'])["Victim Reports"].sem()

statistics_summary_19 = pd.DataFrame({"Mean victim report": victim_report_mean,
                                  "Median victim report": victim_report_median,
                                  "victim report Variance": victim_report_variance,
                                  "victim report Std. Dev.": victim_report_sd,
                                  "victim report Std. Err." : victim_report_SEM,
                                 
                                 })
statistics_summary_19.head(10)
# Out:
#                                    Mean victim report  Median victim report  \
# Offence Division
# A Crimes against the person               3959.000000                  2004
# B Property and deception offences        13143.833333                  7802
# C Other offences                           142.000000                   142
#
#                                    victim report Variance  \
# Offence Division
# A Crimes against the person                  4.318104e+07
# B Property and deception offences            2.292967e+08
# C Other offences                                      NaN
#
#                                    victim report Std. Dev.  \
# Offence Division
# A Crimes against the person                    6571.228110
# B Property and deception offences             15142.546831
# C Other offences                                       NaN
#
#                                    victim report Std. Err.
# Offence Division
# ...

# %%
statistics_raw_data_18=crime_data_18.copy()

victim_report_mean=statistics_raw_data_18.groupby(['Offence Division'])["Victim Reports"].mean()
victim_report_median=statistics_raw_data_18.groupby(['Offence Division'])["Victim Reports"].median()
victim_report_variance=statistics_raw_data_18.groupby(['Offence Division'])["Victim Reports"].var()
victim_report_sd=statistics_raw_data_18.groupby(['Offence Division'])["Victim Reports"].std()
victim_report_SEM=statistics_raw_data_18.groupby(['Offence Division'])["Victim Reports"].sem()

statistics_summary_18 = pd.DataFrame({"Mean victim report": victim_report_mean,
                                  "Median victim report": victim_report_median,
                                  "victim report Variance": victim_report_variance,
                                  "victim report Std. Dev.": victim_report_sd,
                                  "victim report Std. Err." : victim_report_SEM,
                                 
                                 })
statistics_summary_18.head(10)
# Out:
#                                    Mean victim report  Median victim report  \
# Offence Division
# A Crimes against the person               3805.764706                  2059
# B Property and deception offences        12853.000000                  6598
# C Other offences                            91.000000                    91
#
#                                    victim report Variance  \
# Offence Division
# A Crimes against the person                  3.959406e+07
# B Property and deception offences            2.216492e+08
# C Other offences                                      NaN
#
#                                    victim report Std. Dev.  \
# Offence Division
# A Crimes against the person                    6292.381311
# B Property and deception offences             14887.889111
# C Other offences                                       NaN
#
#                                    victim report Std. Err.
# Offence Division
# ...

# %%
bar_plot = crime_data_21['Offence Subdivision'].value_counts().plot.bar(figsize=(5,4))

bar_plot.set_xlabel("Offence Subdivision")
bar_plot.set_ylabel("Number")

plt.tight_layout()
# Out:
# D:\My App\Anaconda\envs\PythonData\lib\site-packages\ipykernel_launcher.py:6: UserWarning: Tight layout not applied. The bottom and top margins cannot be made large enough to accommodate all axes decorations.
